# %%
from music21 import *

# %%
f = music21.note.Note("F5")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 f = music21.note.Note("F5")
#
# AttributeError: module 'music21' has no attribute 'note'

# %%
music21.note
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 music21.note
#
# AttributeError: module 'music21' has no attribute 'note'
